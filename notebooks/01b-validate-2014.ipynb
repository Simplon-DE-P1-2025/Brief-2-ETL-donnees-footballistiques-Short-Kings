# %% [markdown]
# # Extraction - World Cup 2014
#
# **Auteur** : Short Kings Team
# **Date** : 16/12/2025
# **Dataset** : WorldCupMatches2014_1.csv
#
# ## Objectif
# Extraire les données brutes du fichier et identifier les problèmes de qualité

# %% [markdown]
# ## 1. Imports et Configuration

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# Configuration
DATA_PATH = Path('../data/raw/')
OUTPUT_PATH = Path('../data/processed/')

print("Fichiers dans data/raw/ :")
if DATA_PATH.exists():
    for f in DATA_PATH.iterdir():
        print(f"  - {f.name}")
else:
    print("Le dossier n'existe pas!")

# Créer les dossiers si nécessaire
OUTPUT_PATH.mkdir(parents=True, exist_ok=True)
# Out:
# Fichiers dans data/raw/ :
#   - .gitkeep
#   - WorldCupMatches2014 (1).csv

# %% [markdown]
# # 2. Chargement des données brutes

# %%
# Chargement avec le bon séparateur et encodage
# Note: le fichier utilise ';' comme séparateur
df_raw = pd.read_csv(
    DATA_PATH / 'WorldCupMatches2014 (1).csv',
    sep=';',
    encoding='latin-1'  # Pour gérer les caractères spéciaux
)

print(f"Dimensions : {df_raw.shape}")
print(f"Colonnes : {df_raw.columns.tolist()}")
# Out:
# Dimensions : (80, 20)
# Colonnes : ['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name', 'Home Team Goals', 'Away Team Goals', 'Away Team Name', 'Win conditions', 'Attendance', 'Half-time Home Goals', 'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2', 'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials']

# %%
df_raw.head(10)
# Out:
#    Year              Datetime    Stage             Stadium             City  \
# 0  2014  12 Jun 2014 - 17:00   Group A  Arena de Sao Paulo       Sao Paulo
# 1  2014  13 Jun 2014 - 13:00   Group A   Estadio das Dunas           Natal
# 2  2014  13 Jun 2014 - 16:00   Group B    Arena Fonte Nova        Salvador
# 3  2014  13 Jun 2014 - 18:00   Group B      Arena Pantanal          Cuiaba
# 4  2014  14 Jun 2014 - 13:00   Group C    Estadio Mineirao  Belo Horizonte
# 5  2014  14 Jun 2014 - 16:00   Group D    Estadio Castelao       Fortaleza
# 6  2014  14 Jun 2014 - 18:00   Group D      Arena Amazonia          Manaus
# 7  2014  14 Jun 2014 - 22:00   Group C    Arena Pernambuco          Recife
# 8  2014  15 Jun 2014 - 13:00   Group E    Estadio Nacional        Brasilia
# 9  2014  15 Jun 2014 - 16:00   Group E   Estadio Beira-Rio    Porto Alegre
#
#     Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0           Brazil                3                1        Croatia
# 1           Mexico                1                0       Cameroon
# 2            Spain                1                5    Netherlands
# 3            Chile                3                1      Australia
# 4         Colombia                3                0         Greece
# 5          Uruguay                1                3     Costa Rica
# 6          England                1                2          Italy
# 7  Cï¿½te d'Ivoire                2                1          Japan
# 8      Switzerland                2                1        Ecuador
# 9           France                3                0       Honduras
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                    62103.0                     1                     1
# 1                    39216.0                     0                     0
# 2                    48173.0                     1                     1
# 3                    40275.0                     2                     1
# 4                    57174.0                     1                     0
# 5                    58679.0                     1                     0
# 6                    39800.0                     1                     1
# 7                    40267.0                     0                     1
# 8                    68351.0                     0                     1
# 9                    43012.0                     1                     0
#
#                   Referee                  Assistant 1  \
# 0  NISHIMURA Yuichi (JPN)            SAGARA Toru (JPN)
# 1     ROLDAN Wilmar (COL)       CLAVIJO Humberto (COL)
# 2    Nicola RIZZOLI (ITA)        Renato FAVERANI (ITA)
# 3   Noumandiez DOUE (CIV)         YEO Songuifolo (CIV)
# 4       GEIGER Mark (USA)              HURD Sean (USA)
# 5       BRYCH Felix (GER)            BORSCH Mark (GER)
# 6   Bjï¿½rn KUIPERS (NED)      Sander VAN ROEKEL (NED)
# 7     OSSES Enrique (CHI)         ASTROZA Carlos (CHI)
# 8   Ravshan IRMATOV (UZB)  RASULOV Abduxamidullo (UZB)
# 9      RICCI Sandro (BRA)    DE CARVALHO Emerson (BRA)
#
#                      Assistant 2  RoundID    MatchID Home Team Initials  \
# 0           NAGI Toshiyuki (JPN)   255931  300186456                BRA
# 1             DIAZ Eduardo (COL)   255931  300186492                MEX
# 2           Andrea STEFANI (ITA)   255931  300186510                ESP
# 3  BIRUMUSHAHU Jean Claude (BDI)   255931  300186473                CHI
# 4             FLETCHER Joe (CAN)   255931  300186471                COL
# 5              LUPP Stefan (GER)   255931  300186489                URU
# 6           Erwin ZEINSTRA (NED)   255931  300186513                ENG
# 7             ROMAN Sergio (CHI)   255931  300186507                CIV
# 8       KOCHKAROV Bakhadyr (KGZ)   255931  300186494                SUI
# 9        VAN GASSE Marcelo (BRA)   255931  300186496                FRA
#
#   Away Team Initials
# 0                CRO
# 1                CMR
# 2                NED
# 3                AUS
# 4                GRE
# 5                CRC
# 6                ITA
# 7                JPN
# 8                ECU
# 9                HON

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  80 non-null     int64
#  1   Datetime              80 non-null     object
#  2   Stage                 80 non-null     object
#  3   Stadium               80 non-null     object
#  4   City                  80 non-null     object
#  5   Home Team Name        80 non-null     object
#  6   Home Team Goals       80 non-null     int64
#  7   Away Team Goals       80 non-null     int64
#  8   Away Team Name        80 non-null     object
#  9   Win conditions        80 non-null     object
#  10  Attendance            78 non-null     float64
#  11  Half-time Home Goals  80 non-null     int64
#  12  Half-time Away Goals  80 non-null     int64
#  13  Referee               80 non-null     object
#  14  Assistant 1           80 non-null     object
#  15  Assistant 2           80 non-null     object
#  16  RoundID               80 non-null     int64
#  17  MatchID               80 non-null     int64
#  18  Home Team Initials    80 non-null     object
#  19  Away Team Initials    80 non-null     object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 12.6+ KB

# %% [markdown]
# # 3.Analyse de qualité des données
# ## 3.1 Valeurs manquantes

# %%
# Comptage des valeurs manquantes par colonne
missing = df_raw.isnull().sum()
missing_pct = (missing / len(df_raw) * 100).round(2)

missing_report = pd.DataFrame({
    'Valeurs manquantes': missing,
    'Pourcentage (%)': missing_pct
})
missing_report[missing_report['Valeurs manquantes'] > 0]
# Out:
#             Valeurs manquantes  Pourcentage (%)
# Attendance                   2              2.5

# %% [markdown]
# ## 3.2 Détection des doublons

# %%
# Doublons exacts
doublons_exacts = df_raw.duplicated().sum()
print(f"Nombre de doublons exacts : {doublons_exacts}")

# Doublons sur MatchID (identifiant unique supposé)
doublons_matchid = df_raw['MatchID'].duplicated().sum()
print(f"Nombre de MatchID dupliqués : {doublons_matchid}")
# Out:
# Nombre de doublons exacts : 16
# Nombre de MatchID dupliqués : 16

# %%
# Voir les matchs dupliqués
if doublons_matchid > 0:
    matchids_dupliques = df_raw[df_raw['MatchID'].duplicated(keep=False)]['MatchID'].unique()
    print(f"MatchIDs dupliqués : {matchids_dupliques}")
    
    # Afficher un exemple de doublon
    exemple_id = matchids_dupliques[0]
    print(f"\nExemple de doublon (MatchID={exemple_id}) :")
    display(df_raw[df_raw['MatchID'] == exemple_id])
# Out:
# MatchIDs dupliqués : [300186487 300186491 300186462 300186460 300186461 300186485 300186474
#  300186502 300186501 300186490 300186488 300186504 300186508 300186459
#  300186503 300186497]
#
# Exemple de doublon (MatchID=300186487) :
#     Year              Datetime        Stage           Stadium  \
# 48  2014  28 Jun 2014 - 13:00   Round of 16  Estadio Mineirao
# 64  2014  28 Jun 2014 - 13:00   Round of 16  Estadio Mineirao
#
#                City Home Team Name  Home Team Goals  Away Team Goals  \
# 48  Belo Horizonte          Brazil                1                1
# 64  Belo Horizonte          Brazil                1                1
#
#    Away Team Name                    Win conditions  Attendance  \
# 48          Chile  Brazil win on penalties (3 - 2)      57714.0
# 64          Chile  Brazil win on penalties (3 - 2)      57714.0
#
#     Half-time Home Goals  Half-time Away Goals            Referee  \
# 48                     0                     0  WEBB Howard (ENG)
# 64                     0                     0  WEBB Howard (ENG)
#
#                 Assistant 1        Assistant 2  RoundID    MatchID  \
# 48  MULLARKEY Michael (ENG)  Darren CANN (ENG)   255951  300186487
# 64  MULLARKEY Michael (ENG)  Darren CANN (ENG)   255951  300186487
#
#    Home Team Initials Away Team Initials
# 48                BRA                CHI
# 64                BRA                CHI

# %% [markdown]
# ## 3.3 Problèmes d'encodage et données corrompues

# %%
# Vérifier les noms d'équipes uniques
equipes_home = df_raw['Home Team Name'].unique()
equipes_away = df_raw['Away Team Name'].unique()
toutes_equipes = set(equipes_home) | set(equipes_away)

print(f"Nombre d'équipes uniques : {len(toutes_equipes)}")
print("\nListe des équipes :")
for eq in sorted(toutes_equipes):
    print(f"  - '{eq}'")
# Out:
# Nombre d'équipes uniques : 32
#
# Liste des équipes :
#   - 'Algeria'
#   - 'Argentina'
#   - 'Australia'
#   - 'Belgium'
#   - 'Brazil'
#   - 'Cameroon'
#   - 'Chile'
#   - 'Colombia'
#   - 'Costa Rica'
#   - 'Croatia'
#   - 'Cï¿½te d'Ivoire'
#   - 'Ecuador'
#   - 'England'
#   - 'France'
#   - 'Germany'
#   - 'Ghana'
#   - 'Greece'
#   - 'Honduras'
#   - 'IR Iran'
#   - 'Italy'
#   - 'Japan'
#   - 'Korea Republic'
#   - 'Mexico'
#   - 'Netherlands'
#   - 'Nigeria'
#   - 'Portugal'
#   - 'Russia'
#   - 'Spain'
#   - 'Switzerland'
#   - 'USA'
#   - 'Uruguay'
#   - 'rn">Bosnia and Herzegovina'

# %%
# Vérifier les villes
villes = df_raw['City'].unique()
print(f"Villes uniques ({len(villes)}) :")
for v in sorted(villes):
    print(f"  - '{v}'")
# Out:
# Villes uniques (12) :
#   - 'Belo Horizonte '
#   - 'Brasilia '
#   - 'Cuiaba '
#   - 'Curitiba '
#   - 'Fortaleza '
#   - 'Manaus '
#   - 'Natal '
#   - 'Porto Alegre '
#   - 'Recife '
#   - 'Rio De Janeiro '
#   - 'Salvador '
#   - 'Sao Paulo '

# %% [markdown]
# ## 3.4 Analyse des formats de date

# %%
# Échantillon des formats de date
print("Exemples de format de date :")
print(df_raw['Datetime'].head(10).tolist())
# Out:
# Exemples de format de date :
# ['12 Jun 2014 - 17:00 ', '13 Jun 2014 - 13:00 ', '13 Jun 2014 - 16:00 ', '13 Jun 2014 - 18:00 ', '14 Jun 2014 - 13:00 ', '14 Jun 2014 - 16:00 ', '14 Jun 2014 - 18:00 ', '14 Jun 2014 - 22:00 ', '15 Jun 2014 - 13:00 ', '15 Jun 2014 - 16:00 ']

# %% [markdown]
# ## 3.5 Vérification des phases de compétition (Stage)

# %%
# Phases de compétition
stages = df_raw['Stage'].value_counts()
print("Phases de compétition :")
print(stages)
# Out:
# Phases de compétition :
# Stage
# Round of 16                 16
# Quarter-finals               8
# Group A                      6
# Group B                      6
# Group C                      6
# Group D                      6
# Group E                      6
# Group F                      6
# Group G                      6
# Group H                      6
# Semi-finals                  4
# Play-off for third place     2
# Final                        2
# Name: count, dtype: int64
